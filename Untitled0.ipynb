# %% [markdown]
# <a href="https://colab.research.google.com/github/Narit1412/01-Nick-coding68/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
ivelocity = float(input ())
if ivelocity > 120 :
  print('ออกใบสั่ง')
# Out:
# 200
# ออกใบสั่ง

# %%
Time = int(input("Put your time : "))
print("อย่าลืมเอาตังค์ไปโรงเรียนด้วย100บาท!!")
# Out:
# Put your time : 6
# อย่าลืมเอาตังค์ไปโรงเรียนด้วย100บาท!!
